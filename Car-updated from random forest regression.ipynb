# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('car_updated.csv')

# %%
df.head()
# Out:
#                        name    year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007.0          60000    70000.0  Petrol
# 1  Maruti Wagon R LXI Minor  2007.0         135000    50000.0  Petrol
# 2      Hyundai Verna 1.6 SX  2012.0         600000   100000.0     NaN
# 3    Datsun RediGO T Option  2017.0         250000    46000.0  Petrol
# 4     Honda Amaze VX i-DTEC  2014.0         450000   141000.0  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4338 non-null   float64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4336 non-null   float64
#  4   fuel           4337 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4338 non-null   object
#  7   owner          4340 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 271.4+ KB

# %%
df.shape
# Out:
# (4340, 8)

# %%
print(df['seller_type'].unique())
print(df['transmission'].unique())
print(df['owner'].unique())
# Out:
# ['Individual' 'Dealer' 'Trustmark Dealer']
# ['Manual' nan 'Automatic']
# ['First Owner' 'Second Owner' 'Fourth & Above Owner' 'Third Owner'
#  'Test Drive Car']

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
for i in df:
    if df[i].dtypes==object:
        print(df[i].unique())
# Out:
# ['Maruti 800 AC' 'Maruti Wagon R LXI Minor' 'Hyundai Verna 1.6 SX' ...
#  'Mahindra Verito 1.5 D6 BSIII'
#  'Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV'
#  'Hyundai i20 Magna 1.4 CRDi']
# ['Petrol' nan 'Diesel' 'CNG' 'LPG' 'Electric']
# ['Individual' 'Dealer' 'Trustmark Dealer']
# ['Manual' nan 'Automatic']
# ['First Owner' 'Second Owner' 'Fourth & Above Owner' 'Third Owner'
#  'Test Drive Car']

# %%
##check missing values
df.isnull().sum()
# Out:
# name             0
# year             2
# selling_price    0
# km_driven        4
# fuel             3
# seller_type      0
# transmission     2
# owner            0
# dtype: int64

# %%
df[df['km_driven'].isnull()]
# Out:
#                          name    year  selling_price  km_driven    fuel  \
# 11   Tata Indigo Grand Petrol  2014.0         250000        NaN  Petrol
# 16     Datsun RediGO T Option  2017.0         250000        NaN  Petrol
# 19  Hyundai Xcent 1.2 Kappa S  2016.0         550000        NaN  Petrol
# 24   Tata Indigo Grand Petrol     NaN         250000        NaN  Petrol
#
#    seller_type transmission        owner
# 11  Individual       Manual  First Owner
# 16  Individual       Manual  First Owner
# 19  Individual       Manual  First Owner
# 24  Individual       Manual  First Owner

# %%
con=df.describe().columns
cat=df.drop(con,axis=1).columns

# %%
for i in df[con]:
    df[i].replace(np.nan,df[i].median(),inplace=True)

# %%
for i in df[cat]:
    df[i].replace(np.nan,df[i].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#                           name         year  selling_price      km_driven  \
# count                     4340  4340.000000   4.340000e+03    4340.000000
# unique                    1491          NaN            NaN            NaN
# top     Maruti Swift Dzire VDI          NaN            NaN            NaN
# freq                        69          NaN            NaN            NaN
# mean                       NaN  2013.090783   5.041273e+05   66208.634562
# std                        NaN     4.215344   5.785487e+05   46633.636399
# min                        NaN  1992.000000   2.000000e+04       1.000000
# 25%                        NaN  2011.000000   2.087498e+05   35000.000000
# 50%                        NaN  2014.000000   3.500000e+05   60000.000000
# 75%                        NaN  2016.000000   6.000000e+05   90000.000000
# max                        NaN  2020.000000   8.900000e+06  806599.000000
#
#           fuel seller_type transmission        owner
# ...

# %%
df.head()
# Out:
#                        name    year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007.0          60000    70000.0  Petrol
# 1  Maruti Wagon R LXI Minor  2007.0         135000    50000.0  Petrol
# 2      Hyundai Verna 1.6 SX  2012.0         600000   100000.0  Diesel
# 3    Datsun RediGO T Option  2017.0         250000    46000.0  Petrol
# 4     Honda Amaze VX i-DTEC  2014.0         450000   141000.0  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
#Now REmoving car names because based on car name we cant judge selling price
fina_dataset=df[['year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
       'transmission', 'owner']]

# %%
fina_dataset.head()
# Out:
#      year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2007.0          60000    70000.0  Petrol  Individual       Manual
# 1  2007.0         135000    50000.0  Petrol  Individual       Manual
# 2  2012.0         600000   100000.0  Diesel  Individual       Manual
# 3  2017.0         250000    46000.0  Petrol  Individual       Manual
# 4  2014.0         450000   141000.0  Diesel  Individual       Manual
#
#           owner
# 0   First Owner
# 1   First Owner
# 2   First Owner
# 3   First Owner
# 4  Second Owner

# %%
fina_dataset['Current_year']=2020

# %%
fina_dataset.head()
# Out:
#      year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2007.0          60000    70000.0  Petrol  Individual       Manual
# 1  2007.0         135000    50000.0  Petrol  Individual       Manual
# 2  2012.0         600000   100000.0  Diesel  Individual       Manual
# 3  2017.0         250000    46000.0  Petrol  Individual       Manual
# 4  2014.0         450000   141000.0  Diesel  Individual       Manual
#
#           owner  Current_year
# 0   First Owner          2020
# 1   First Owner          2020
# 2   First Owner          2020
# 3   First Owner          2020
# 4  Second Owner          2020

# %%
fina_dataset['no_year']=fina_dataset['Current_year']-fina_dataset['year']

# %%
fina_dataset.head()
# Out:
#      year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2007.0          60000    70000.0  Petrol  Individual       Manual
# 1  2007.0         135000    50000.0  Petrol  Individual       Manual
# 2  2012.0         600000   100000.0  Diesel  Individual       Manual
# 3  2017.0         250000    46000.0  Petrol  Individual       Manual
# 4  2014.0         450000   141000.0  Diesel  Individual       Manual
#
#           owner  Current_year  no_year
# 0   First Owner          2020     13.0
# 1   First Owner          2020     13.0
# 2   First Owner          2020      8.0
# 3   First Owner          2020      3.0
# 4  Second Owner          2020      6.0

# %%
fina_dataset.drop(['year','Current_year'],axis=1,inplace=True)

# %%
fina_dataset.head()
# Out:
#    selling_price  km_driven    fuel seller_type transmission         owner  \
# 0          60000    70000.0  Petrol  Individual       Manual   First Owner
# 1         135000    50000.0  Petrol  Individual       Manual   First Owner
# 2         600000   100000.0  Diesel  Individual       Manual   First Owner
# 3         250000    46000.0  Petrol  Individual       Manual   First Owner
# 4         450000   141000.0  Diesel  Individual       Manual  Second Owner
#
#    no_year
# 0     13.0
# 1     13.0
# 2      8.0
# 3      3.0
# 4      6.0

# %%
fina_dataset=pd.get_dummies(data=fina_dataset,drop_first=True)

# %%
fina_dataset.head()
# Out:
#    selling_price  km_driven  no_year  fuel_Diesel  fuel_Electric  fuel_LPG  \
# 0          60000    70000.0     13.0            0              0         0
# 1         135000    50000.0     13.0            0              0         0
# 2         600000   100000.0      8.0            1              0         0
# 3         250000    46000.0      3.0            0              0         0
# 4         450000   141000.0      6.0            1              0         0
#
#    fuel_Petrol  seller_type_Individual  seller_type_Trustmark Dealer  \
# 0            1                       1                             0
# 1            1                       1                             0
# 2            0                       1                             0
# 3            1                       1                             0
# 4            0                       1                             0
#
#    transmission_Manual  owner_Fourth & Above Owner  owner_Second Owner  \
# ...

# %%
# To find correlation
fina_dataset.corr()
# Out:
#                               selling_price  km_driven   no_year  fuel_Diesel  \
# selling_price                      1.000000  -0.192175 -0.413922     0.282544
# km_driven                         -0.192175   1.000000  0.419684     0.286308
# no_year                           -0.413922   0.419684  1.000000    -0.121185
# fuel_Diesel                        0.282544   0.286308 -0.121185     1.000000
# fuel_Electric                     -0.005095  -0.001370  0.025540    -0.015077
# fuel_LPG                          -0.042434   0.036671  0.051266    -0.072489
# fuel_Petrol                       -0.269166  -0.291945  0.114243    -0.971382
# seller_type_Individual            -0.236798   0.182615  0.173703    -0.034778
# seller_type_Trustmark Dealer       0.110176  -0.089854 -0.100225    -0.008054
# transmission_Manual               -0.529228   0.119650  0.143060    -0.048585
# owner_Fourth & Above Owner        -0.078725   0.097392  0.186361    -0.021181
# ...

# %%
# to display in diagrametic way
import seaborn as sns

# %%
sns.pairplot(fina_dataset)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# we try to put this as heat map
corrmat=fina_dataset.corr()
top_corr_features=corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(fina_dataset[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
plt.figure(figsize=(20,20))
sns.heatmap(fina_dataset.corr(),annot=True,cmap="RdYlGn")
# Out:
# <AxesSubplot:>

# %% [markdown]
# if the correlation is heigher than 0.8 & if the correlation is less tha 0.8 <br>then you can probably
# drop down one of the feature because both features are doing same kind of work.

# %%
X=fina_dataset.iloc[:,1:]
y=fina_dataset.iloc[:,0]

# %%
X.head()
# Out:
#    km_driven  no_year  fuel_Diesel  fuel_Electric  fuel_LPG  fuel_Petrol  \
# 0    70000.0     13.0            0              0         0            1
# 1    50000.0     13.0            0              0         0            1
# 2   100000.0      8.0            1              0         0            0
# 3    46000.0      3.0            0              0         0            1
# 4   141000.0      6.0            1              0         0            0
#
#    seller_type_Individual  seller_type_Trustmark Dealer  transmission_Manual  \
# 0                       1                             0                    1
# 1                       1                             0                    1
# 2                       1                             0                    1
# 3                       1                             0                    1
# 4                       1                             0                    1
#
# ...

# %%
y.head()
# Out:
# 0     60000
# 1    135000
# 2    600000
# 3    250000
# 4    450000
# Name: selling_price, dtype: int64

# %%
# faeture importance
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(X,y)
# To predict which features are really importance
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# so first feature re more importance  than rest areacording to position
# Out:
# [2.47633165e-01 2.47401908e-01 1.29942008e-01 3.79091309e-05
#  2.53069069e-05 2.12986987e-04 4.75822757e-02 8.07382835e-03
#  2.91762037e-01 7.87347822e-04 2.19121739e-02 4.67096293e-04
#  4.16195745e-03]

# %%
feat_importance=pd.Series(model.feature_importances_,index=X.columns)
feat_importance.nlargest(5).plot(kind='barh')
# To see 5 more important features
# Out:
# <AxesSubplot:>

# %%
# Train_test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train.shape
# Out:
# (3472, 13)

# %%
y_train.shape
# Out:
# (3472,)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_random=RandomForestRegressor()

# %%
###Hyperparameters
# Number of trees in random forest
n_estimators=[int(x) for x in np.linspace(start=100, stop=1200,num=12)]
# Number of features to consider at every split
max_features=['auto','sqrt']
# maximum no. of levels in tree
max_depth=[int(x) for x in np.linspace(5,30, num=6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf=[1,2,5,10]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
rf = RandomForestRegressor()

# %%
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs=1)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   2.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   2.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   2.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   2.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   2.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   3.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   3.7s
# ...

# %%
# Now i am goin to do my prediction
predictions=rf_random.predict(X_test)

# %%
predictions
# Out:
# array([ 463246.20492264,  152730.46780197,  246576.84721801,
#         298041.39366731,  415327.66054036,  197814.91329983,
#         195116.88170604,  218028.18350225,  456708.85133907,
#         327668.30793703,  773790.77310467,  113053.31484716,
#        1099586.85016552,  104797.2130872 ,  448537.59722478,
#         509624.10620233,  485928.95490195,  208619.7976464 ,
#         335051.89283824,  327668.30793703,  201260.81372006,
#         427840.31725493,  198773.03070822,  572371.58436658,
#         735312.49063804, 1924642.55278321,  582989.27528448,
#         483673.37591398,  134389.74878982,  464981.53883032,
#         457424.68275331,  475852.70934248,  199352.18227674,
#        1374337.5480609 , 2254739.70862953,  178794.22668289,
#         542916.62128695,  583675.06831015,  428386.03012101,
#         226367.28420805, 1468421.39062914,  644953.71163151,
#        1275032.94863344,  120140.95942846,  360902.28466733,
# ...

# %%
# to campare it use dist plot
sns.distplot(y_test-predictions)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='selling_price', ylabel='Density'>

# %% [markdown]
# so this difference is showing normal distribution:)<br>also this difference between y_test and prediction should be minimum<br> so geeting is this distribution graph:)

# %%
plt.scatter(y_test,predictions)

# %% [markdown]
# also here Y_test and predictions lie very close to each other

# %%
import pickle
# open a file, where you ant to store the data
file = open('random_forest_regression_model.pkl', 'wb')

# dump information to that file
pickle.dump(rf_random, file)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 186280.74825311228
# MSE: 188788883292.21542
# RMSE: 434498.4272609228

# %%
# Out:
# Deepak : 40000
